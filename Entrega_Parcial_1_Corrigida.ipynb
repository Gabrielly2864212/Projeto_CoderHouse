# %% [markdown]
# CONEXÃO COM 1ª API PARA EXTRAÇÃO DE UMA TABELA

# %%
# Importação das Bibliotecas

import requests
import pandas as pd
from plyer import notification

# %%
# Extraindo a Tabela da API

# Definindo a URL da API
url = 'https://brasilapi.com.br/api/banks/v1'

# Função para extrair dados da API
def fetch_data(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Verifica se a requisição foi bem-sucedida
        data = response.json()
        return data
    except requests.exceptions.RequestException as e:
        # Se ocorrer um erro, exibe uma notificação
        notification.notify(
            title='Erro na Requisição',
            message=f'Ocorreu um erro ao acessar a API: {e}',
            timeout=10
        )
        print(f'Erro: {e}')
        return None

# %%
# Processamento de Dados

# Função para converter dados em DataFrame
def process_data(data):
    if data is None:
        return None
    # Convertendo dados para DataFrame
    df = pd.DataFrame(data)
    return df

# Obtendo dados da API
data = fetch_data(url)

# Processando os dados
df = process_data(data)

# Exibindo os primeiros registros do DataFrame
if df is not None:
    print(df.head())
# Out:
#        ispb                        name   code  \
# 0  00000000          BCO DO BRASIL S.A.    1.0
# 1  00000208  BRB - BCO DE BRASILIA S.A.   70.0
# 2  00038121                       Selic    NaN
# 3  00038166                       Bacen    NaN
# 4  00122327       SANTINVEST S.A. - CFI  539.0
#
#                                             fullName
# 0                               Banco do Brasil S.A.
# 1                       BRB - BANCO DE BRASILIA S.A.
# 2                    Banco Central do Brasil - Selic
# 3                            Banco Central do Brasil
# 4  SANTINVEST S.A. - CREDITO, FINANCIAMENTO E INV...

# %%
# Exibindo um alerta de sucesso

# Se o DataFrame não estiver vazio, exibe uma notificação de sucesso
if df is not None and not df.empty:
    notification.notify(
        title='Dados Extraídos com Sucesso',
        message='Os dados foram extraídos e estruturados com sucesso!',
        timeout=10
    )

# %% [markdown]
# CONEXÃO COM 2ª API PARA EXTRAÇÃO DE UMA TABELA

# %%
# Importação das Bibliotecas

import requests
from plyer import notification

# %%
# Extraindo dados da API

def fetch_data_from_api(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Levanta um erro para códigos de status HTTP 4xx/5xx
        return response.json()
    except requests.RequestException as e:
        # Alerta de erro sonoro
        notification.notify(
            title='Erro na Extração de Dados',
            message=str(e),
            timeout=10
        )
        print(f"Erro ao acessar a API: {e}")
        return None

# %%
# Processamento dos Dados

def process_data(data):
    if not data:
        return None
    processed_data = []
    for country in data:
        try:
            name = country.get('name', {}).get('common', 'N/A')
            capital = country.get('capital', ['N/A'])[0]
            region = country.get('region', 'N/A')
            population = country.get('population', 'N/A')
            processed_data.append({
                'name': name,
                'capital': capital,
                'region': region,
                'population': population
            })
        except Exception as e:
            print(f"Erro ao processar dados do país: {e}")
    return processed_data

# %%
# Executando o Código

def main():
    url = 'https://restcountries.com/v3.1/all'
    data = fetch_data_from_api(url)
    processed_data = process_data(data)
    if processed_data:
        for entry in processed_data:
            print(entry)

if __name__ == "__main__":
    main()
# Out:
# {'name': 'South Georgia', 'capital': 'King Edward Point', 'region': 'Antarctic', 'population': 30}
# {'name': 'Grenada', 'capital': "St. George's", 'region': 'Americas', 'population': 112519}
# {'name': 'Switzerland', 'capital': 'Bern', 'region': 'Europe', 'population': 8654622}
# {'name': 'Sierra Leone', 'capital': 'Freetown', 'region': 'Africa', 'population': 7976985}
# {'name': 'Hungary', 'capital': 'Budapest', 'region': 'Europe', 'population': 9749763}
# {'name': 'Taiwan', 'capital': 'Taipei', 'region': 'Asia', 'population': 23503349}
# {'name': 'Wallis and Futuna', 'capital': 'Mata-Utu', 'region': 'Oceania', 'population': 11750}
# {'name': 'Barbados', 'capital': 'Bridgetown', 'region': 'Americas', 'population': 287371}
# {'name': 'Pitcairn Islands', 'capital': 'Adamstown', 'region': 'Oceania', 'population': 56}
# {'name': 'Ivory Coast', 'capital': 'Yamoussoukro', 'region': 'Africa', 'population': 26378275}
# {'name': 'Tunisia', 'capital': 'Tunis', 'region': 'Africa', 'population': 11818618}
# {'name': 'Italy', 'capital': 'Rome', 'region': 'Europe', 'population': 59554023}
# {'name': 'Benin', 'capital': 'Porto-Novo', 'region': 'Africa', 'population': 12123198}
# {'name': 'Indonesia', 'capital': 'Jakarta', 'region': 'Asia', 'population': 273523621}
# {'name': 'Cape Verde', 'capital': 'Praia', 'region': 'Africa', 'population': 555988}
# {'name': 'Saint Kitts and Nevis', 'capital': 'Basseterre', 'region': 'Americas', 'population': 53192}
# {'name': 'Laos', 'capital': 'Vientiane', 'region': 'Asia', 'population': 7275556}
# {'name': 'Caribbean Netherlands', 'capital': 'Kralendijk', 'region': 'Americas', 'population': 25987}
# {'name': 'Uganda', 'capital': 'Kampala', 'region': 'Africa', 'population': 45741000}
# {'name': 'Andorra', 'capital': 'Andorra la Vella', 'region': 'Europe', 'population': 77265}
# {'name': 'Burundi', 'capital': 'Gitega', 'region': 'Africa', 'population': 11890781}
# {'name': 'South Africa', 'capital': 'Pretoria', 'region': 'Africa', 'population': 59308690}
# {'name': 'France', 'capital': 'Paris', 'region': 'Europe', 'population': 67391582}
# {'name': 'Libya', 'capital': 'Tripoli', 'region': 'Africa', 'population': 6871287}
# {'name': 'Mexico', 'capital': 'Mexico City', 'region': 'Americas', 'population': 128932753}
# {'name': 'Gabon', 'capital': 'Libreville', 'region': 'Africa', 'population': 2225728}
# {'name': 'Northern Mariana Islands', 'capital': 'Saipan', 'region': 'Oceania', 'population': 57557}
# {'name': 'North Macedonia', 'capital': 'Skopje', 'region': 'Europe', 'population': 2077132}
# {'name': 'China', 'capital': 'Beijing', 'region': 'Asia', 'population': 1402112000}
# {'name': 'Yemen', 'capital': "Sana'a", 'region': 'Asia', 'population': 29825968}
# {'name': 'Saint Barthélemy', 'capital': 'Gustavia', 'region': 'Americas', 'population': 4255}
# {'name': 'Guernsey', 'capital': 'St. Peter Port', 'region': 'Europe', 'population': 62999}
# {'name': 'Solomon Islands', 'capital': 'Honiara', 'region': 'Oceania', 'population': 686878}
# {'name': 'Svalbard and Jan Mayen', 'capital': 'Longyearbyen', 'region': 'Europe', 'population': 2562}
# {'name': 'Faroe Islands', 'capital': 'Tórshavn', 'region': 'Europe', 'population': 48865}
# {'name': 'Uzbekistan', 'capital': 'Tashkent', 'region': 'Asia', 'population': 34232050}
# {'name': 'Egypt', 'capital': 'Cairo', 'region': 'Africa', 'population': 102334403}
# {'name': 'Senegal', 'capital': 'Dakar', 'region': 'Africa', 'population': 16743930}
# {'name': 'Sri Lanka', 'capital': 'Sri Jayawardenepura Kotte', 'region': 'Asia', 'population': 21919000}
# {'name': 'Palestine', 'capital': 'Ramallah', 'region': 'Asia', 'population': 4803269}
# {'name': 'Bangladesh', 'capital': 'Dhaka', 'region': 'Asia', 'population': 164689383}
# {'name': 'Peru', 'capital': 'Lima', 'region': 'Americas', 'population': 32971846}
# {'name': 'Singapore', 'capital': 'Singapore', 'region': 'Asia', 'population': 5685807}
# {'name': 'Turkey', 'capital': 'Ankara', 'region': 'Asia', 'population': 84339067}
# {'name': 'Afghanistan', 'capital': 'Kabul', 'region': 'Asia', 'population': 40218234}
# {'name': 'Aruba', 'capital': 'Oranjestad', 'region': 'Americas', 'population': 106766}
# {'name': 'Cook Islands', 'capital': 'Avarua', 'region': 'Oceania', 'population': 18100}
# {'name': 'United Kingdom', 'capital': 'London', 'region': 'Europe', 'population': 67215293}
# {'name': 'Zambia', 'capital': 'Lusaka', 'region': 'Africa', 'population': 18383956}
# {'name': 'Finland', 'capital': 'Helsinki', 'region': 'Europe', 'population': 5530719}
# {'name': 'Niger', 'capital': 'Niamey', 'region': 'Africa', 'population': 24206636}
# {'name': 'Christmas Island', 'capital': 'Flying Fish Cove', 'region': 'Oceania', 'population': 2072}
# {'name': 'Tokelau', 'capital': 'Fakaofo', 'region': 'Oceania', 'population': 1411}
# {'name': 'Guinea-Bissau', 'capital': 'Bissau', 'region': 'Africa', 'population': 1967998}
# {'name': 'Azerbaijan', 'capital': 'Baku', 'region': 'Asia', 'population': 10110116}
# {'name': 'Réunion', 'capital': 'Saint-Denis', 'region': 'Africa', 'population': 840974}
# {'name': 'Djibouti', 'capital': 'Djibouti', 'region': 'Africa', 'population': 988002}
# {'name': 'North Korea', 'capital': 'Pyongyang', 'region': 'Asia', 'population': 25778815}
# {'name': 'Mauritius', 'capital': 'Port Louis', 'region': 'Africa', 'population': 1265740}
# {'name': 'Montserrat', 'capital': 'Plymouth', 'region': 'Americas', 'population': 4922}
# {'name': 'United States Virgin Islands', 'capital': 'Charlotte Amalie', 'region': 'Americas', 'population': 106290}
# {'name': 'Colombia', 'capital': 'Bogotá', 'region': 'Americas', 'population': 50882884}
# {'name': 'Greece', 'capital': 'Athens', 'region': 'Europe', 'population': 10715549}
# {'name': 'Croatia', 'capital': 'Zagreb', 'region': 'Europe', 'population': 4047200}
# {'name': 'Morocco', 'capital': 'Rabat', 'region': 'Africa', 'population': 36910558}
# {'name': 'Algeria', 'capital': 'Algiers', 'region': 'Africa', 'population': 44700000}
# {'name': 'Antarctica', 'capital': 'N/A', 'region': 'Antarctic', 'population': 1000}
# {'name': 'Netherlands', 'capital': 'Amsterdam', 'region': 'Europe', 'population': 16655799}
# {'name': 'Sudan', 'capital': 'Khartoum', 'region': 'Africa', 'population': 43849269}
# {'name': 'Fiji', 'capital': 'Suva', 'region': 'Oceania', 'population': 896444}
# {'name': 'Liechtenstein', 'capital': 'Vaduz', 'region': 'Europe', 'population': 38137}
# {'name': 'Nepal', 'capital': 'Kathmandu', 'region': 'Asia', 'population': 29136808}
# {'name': 'Puerto Rico', 'capital': 'San Juan', 'region': 'Americas', 'population': 3194034}
# {'name': 'Georgia', 'capital': 'Tbilisi', 'region': 'Asia', 'population': 3714000}
# {'name': 'Pakistan', 'capital': 'Islamabad', 'region': 'Asia', 'population': 220892331}
# {'name': 'Monaco', 'capital': 'Monaco', 'region': 'Europe', 'population': 39244}
# {'name': 'Botswana', 'capital': 'Gaborone', 'region': 'Africa', 'population': 2351625}
# {'name': 'Lebanon', 'capital': 'Beirut', 'region': 'Asia', 'population': 6825442}
# {'name': 'Papua New Guinea', 'capital': 'Port Moresby', 'region': 'Oceania', 'population': 8947027}
# {'name': 'Mayotte', 'capital': 'Mamoudzou', 'region': 'Africa', 'population': 226915}
# {'name': 'Dominican Republic', 'capital': 'Santo Domingo', 'region': 'Americas', 'population': 10847904}
# {'name': 'Norfolk Island', 'capital': 'Kingston', 'region': 'Oceania', 'population': 2302}
# {'name': 'Bouvet Island', 'capital': 'N/A', 'region': 'Antarctic', 'population': 0}
# {'name': 'Qatar', 'capital': 'Doha', 'region': 'Asia', 'population': 2881060}
# {'name': 'Madagascar', 'capital': 'Antananarivo', 'region': 'Africa', 'population': 27691019}
# {'name': 'India', 'capital': 'New Delhi', 'region': 'Asia', 'population': 1380004385}
# {'name': 'Syria', 'capital': 'Damascus', 'region': 'Asia', 'population': 17500657}
# {'name': 'Montenegro', 'capital': 'Podgorica', 'region': 'Europe', 'population': 621718}
# {'name': 'Eswatini', 'capital': 'Mbabane', 'region': 'Africa', 'population': 1160164}
# {'name': 'Paraguay', 'capital': 'Asunción', 'region': 'Americas', 'population': 7132530}
# {'name': 'El Salvador', 'capital': 'San Salvador', 'region': 'Americas', 'population': 6486201}
# {'name': 'Ukraine', 'capital': 'Kyiv', 'region': 'Europe', 'population': 44134693}
# {'name': 'Isle of Man', 'capital': 'Douglas', 'region': 'Europe', 'population': 85032}
# {'name': 'Namibia', 'capital': 'Windhoek', 'region': 'Africa', 'population': 2540916}
# {'name': 'United Arab Emirates', 'capital': 'Abu Dhabi', 'region': 'Asia', 'population': 9890400}
# {'name': 'Bulgaria', 'capital': 'Sofia', 'region': 'Europe', 'population': 6927288}
# {'name': 'Greenland', 'capital': 'Nuuk', 'region': 'Americas', 'population': 56367}
# {'name': 'Germany', 'capital': 'Berlin', 'region': 'Europe', 'population': 83240525}
# {'name': 'Cambodia', 'capital': 'Phnom Penh', 'region': 'Asia', 'population': 16718971}
# {'name': 'Iraq', 'capital': 'Baghdad', 'region': 'Asia', 'population': 40222503}
# {'name': 'French Southern and Antarctic Lands', 'capital': 'Port-aux-Français', 'region': 'Antarctic', 'population': 400}
# {'name': 'Sweden', 'capital': 'Stockholm', 'region': 'Europe', 'population': 10353442}
# {'name': 'Cuba', 'capital': 'Havana', 'region': 'Americas', 'population': 11326616}
# {'name': 'Kyrgyzstan', 'capital': 'Bishkek', 'region': 'Asia', 'population': 6591600}
# {'name': 'Russia', 'capital': 'Moscow', 'region': 'Europe', 'population': 144104080}
# {'name': 'Malaysia', 'capital': 'Kuala Lumpur', 'region': 'Asia', 'population': 32365998}
# {'name': 'São Tomé and Príncipe', 'capital': 'São Tomé', 'region': 'Africa', 'population': 219161}
# {'name': 'Cyprus', 'capital': 'Nicosia', 'region': 'Europe', 'population': 1207361}
# {'name': 'Canada', 'capital': 'Ottawa', 'region': 'Americas', 'population': 38005238}
# {'name': 'Malawi', 'capital': 'Lilongwe', 'region': 'Africa', 'population': 19129955}
# {'name': 'Saudi Arabia', 'capital': 'Riyadh', 'region': 'Asia', 'population': 34813867}
# {'name': 'Bosnia and Herzegovina', 'capital': 'Sarajevo', 'region': 'Europe', 'population': 3280815}
# {'name': 'Ethiopia', 'capital': 'Addis Ababa', 'region': 'Africa', 'population': 114963583}
# {'name': 'Spain', 'capital': 'Madrid', 'region': 'Europe', 'population': 47351567}
# {'name': 'Slovenia', 'capital': 'Ljubljana', 'region': 'Europe', 'population': 2100126}
# {'name': 'Oman', 'capital': 'Muscat', 'region': 'Asia', 'population': 5106622}
# {'name': 'Saint Pierre and Miquelon', 'capital': 'Saint-Pierre', 'region': 'Americas', 'population': 6069}
# {'name': 'Macau', 'capital': 'N/A', 'region': 'Asia', 'population': 649342}
# {'name': 'San Marino', 'capital': 'City of San Marino', 'region': 'Europe', 'population': 33938}
# {'name': 'Lesotho', 'capital': 'Maseru', 'region': 'Africa', 'population': 2142252}
# {'name': 'Marshall Islands', 'capital': 'Majuro', 'region': 'Oceania', 'population': 59194}
# {'name': 'Sint Maarten', 'capital': 'Philipsburg', 'region': 'Americas', 'population': 40812}
# {'name': 'Iceland', 'capital': 'Reykjavik', 'region': 'Europe', 'population': 366425}
# {'name': 'Luxembourg', 'capital': 'Luxembourg', 'region': 'Europe', 'population': 632275}
# {'name': 'Argentina', 'capital': 'Buenos Aires', 'region': 'Americas', 'population': 45376763}
# {'name': 'Turks and Caicos Islands', 'capital': 'Cockburn Town', 'region': 'Americas', 'population': 38718}
# {'name': 'Nauru', 'capital': 'Yaren', 'region': 'Oceania', 'population': 10834}
# {'name': 'Cocos (Keeling) Islands', 'capital': 'West Island', 'region': 'Oceania', 'population': 544}
# {'name': 'Western Sahara', 'capital': 'El Aaiún', 'region': 'Africa', 'population': 510713}
# {'name': 'Dominica', 'capital': 'Roseau', 'region': 'Americas', 'population': 71991}
# {'name': 'Costa Rica', 'capital': 'San José', 'region': 'Americas', 'population': 5094114}
# {'name': 'Australia', 'capital': 'Canberra', 'region': 'Oceania', 'population': 25687041}
# {'name': 'Thailand', 'capital': 'Bangkok', 'region': 'Asia', 'population': 69799978}
# {'name': 'Haiti', 'capital': 'Port-au-Prince', 'region': 'Americas', 'population': 11402533}
# {'name': 'Tuvalu', 'capital': 'Funafuti', 'region': 'Oceania', 'population': 11792}
# {'name': 'Honduras', 'capital': 'Tegucigalpa', 'region': 'Americas', 'population': 9904608}
# {'name': 'Equatorial Guinea', 'capital': 'Malabo', 'region': 'Africa', 'population': 1402985}
# {'name': 'Saint Lucia', 'capital': 'Castries', 'region': 'Americas', 'population': 183629}
# {'name': 'French Polynesia', 'capital': 'Papeetē', 'region': 'Oceania', 'population': 280904}
# {'name': 'Belarus', 'capital': 'Minsk', 'region': 'Europe', 'population': 9398861}
# {'name': 'Latvia', 'capital': 'Riga', 'region': 'Europe', 'population': 1901548}
# {'name': 'Palau', 'capital': 'Ngerulmud', 'region': 'Oceania', 'population': 18092}
# {'name': 'Guadeloupe', 'capital': 'Basse-Terre', 'region': 'Americas', 'population': 400132}
# {'name': 'Philippines', 'capital': 'Manila', 'region': 'Asia', 'population': 109581085}
# {'name': 'Gibraltar', 'capital': 'Gibraltar', 'region': 'Europe', 'population': 33691}
# {'name': 'Denmark', 'capital': 'Copenhagen', 'region': 'Europe', 'population': 5831404}
# {'name': 'Cameroon', 'capital': 'Yaoundé', 'region': 'Africa', 'population': 26545864}
# {'name': 'Guinea', 'capital': 'Conakry', 'region': 'Africa', 'population': 13132792}
# {'name': 'Bahrain', 'capital': 'Manama', 'region': 'Asia', 'population': 1701583}
# {'name': 'Suriname', 'capital': 'Paramaribo', 'region': 'Americas', 'population': 586634}
# {'name': 'DR Congo', 'capital': 'Kinshasa', 'region': 'Africa', 'population': 108407721}
# {'name': 'Somalia', 'capital': 'Mogadishu', 'region': 'Africa', 'population': 15893219}
# {'name': 'Czechia', 'capital': 'Prague', 'region': 'Europe', 'population': 10698896}
# {'name': 'New Caledonia', 'capital': 'Nouméa', 'region': 'Oceania', 'population': 271960}
# {'name': 'Vanuatu', 'capital': 'Port Vila', 'region': 'Oceania', 'population': 307150}
# {'name': 'Saint Helena, Ascension and Tristan da Cunha', 'capital': 'Jamestown', 'region': 'Africa', 'population': 53192}
# {'name': 'Togo', 'capital': 'Lomé', 'region': 'Africa', 'population': 8278737}
# {'name': 'British Virgin Islands', 'capital': 'Road Town', 'region': 'Americas', 'population': 30237}
# {'name': 'Kenya', 'capital': 'Nairobi', 'region': 'Africa', 'population': 53771300}
# {'name': 'Niue', 'capital': 'Alofi', 'region': 'Oceania', 'population': 1470}
# {'name': 'Heard Island and McDonald Islands', 'capital': 'N/A', 'region': 'Antarctic', 'population': 0}
# {'name': 'Rwanda', 'capital': 'Kigali', 'region': 'Africa', 'population': 12952209}
# {'name': 'Estonia', 'capital': 'Tallinn', 'region': 'Europe', 'population': 1331057}
# {'name': 'Romania', 'capital': 'Bucharest', 'region': 'Europe', 'population': 19286123}
# {'name': 'Trinidad and Tobago', 'capital': 'Port of Spain', 'region': 'Americas', 'population': 1399491}
# {'name': 'Guyana', 'capital': 'Georgetown', 'region': 'Americas', 'population': 786559}
# {'name': 'Timor-Leste', 'capital': 'Dili', 'region': 'Asia', 'population': 1318442}
# {'name': 'Vietnam', 'capital': 'Hanoi', 'region': 'Asia', 'population': 97338583}
# {'name': 'Uruguay', 'capital': 'Montevideo', 'region': 'Americas', 'population': 3473727}
# {'name': 'Vatican City', 'capital': 'Vatican City', 'region': 'Europe', 'population': 451}
# {'name': 'Hong Kong', 'capital': 'City of Victoria', 'region': 'Asia', 'population': 7500700}
# {'name': 'Austria', 'capital': 'Vienna', 'region': 'Europe', 'population': 8917205}
# {'name': 'Antigua and Barbuda', 'capital': "Saint John's", 'region': 'Americas', 'population': 97928}
# {'name': 'Turkmenistan', 'capital': 'Ashgabat', 'region': 'Asia', 'population': 6031187}
# {'name': 'Mozambique', 'capital': 'Maputo', 'region': 'Africa', 'population': 31255435}
# {'name': 'Panama', 'capital': 'Panama City', 'region': 'Americas', 'population': 4314768}
# {'name': 'Micronesia', 'capital': 'Palikir', 'region': 'Oceania', 'population': 115021}
# {'name': 'Ireland', 'capital': 'Dublin', 'region': 'Europe', 'population': 4994724}
# {'name': 'Curaçao', 'capital': 'Willemstad', 'region': 'Americas', 'population': 155014}
# {'name': 'French Guiana', 'capital': 'Cayenne', 'region': 'Americas', 'population': 254541}
# {'name': 'Norway', 'capital': 'Oslo', 'region': 'Europe', 'population': 5379475}
# {'name': 'Åland Islands', 'capital': 'Mariehamn', 'region': 'Europe', 'population': 29458}
# {'name': 'Central African Republic', 'capital': 'Bangui', 'region': 'Africa', 'population': 4829764}
# {'name': 'Burkina Faso', 'capital': 'Ouagadougou', 'region': 'Africa', 'population': 20903278}
# {'name': 'Eritrea', 'capital': 'Asmara', 'region': 'Africa', 'population': 5352000}
# {'name': 'Tanzania', 'capital': 'Dodoma', 'region': 'Africa', 'population': 59734213}
# {'name': 'South Korea', 'capital': 'Seoul', 'region': 'Asia', 'population': 51780579}
# {'name': 'Jordan', 'capital': 'Amman', 'region': 'Asia', 'population': 10203140}
# {'name': 'Mauritania', 'capital': 'Nouakchott', 'region': 'Africa', 'population': 4649660}
# {'name': 'Lithuania', 'capital': 'Vilnius', 'region': 'Europe', 'population': 2794700}
# {'name': 'United States Minor Outlying Islands', 'capital': 'Washington DC', 'region': 'Americas', 'population': 300}
# {'name': 'Slovakia', 'capital': 'Bratislava', 'region': 'Europe', 'population': 5458827}
# {'name': 'Angola', 'capital': 'Luanda', 'region': 'Africa', 'population': 32866268}
# {'name': 'Kazakhstan', 'capital': 'Nur-Sultan', 'region': 'Asia', 'population': 18754440}
# {'name': 'Moldova', 'capital': 'Chișinău', 'region': 'Europe', 'population': 2617820}
# {'name': 'Mali', 'capital': 'Bamako', 'region': 'Africa', 'population': 20250834}
# {'name': 'Falkland Islands', 'capital': 'Stanley', 'region': 'Americas', 'population': 2563}
# {'name': 'Armenia', 'capital': 'Yerevan', 'region': 'Asia', 'population': 2963234}
# {'name': 'Samoa', 'capital': 'Apia', 'region': 'Oceania', 'population': 198410}
# {'name': 'Jersey', 'capital': 'Saint Helier', 'region': 'Europe', 'population': 100800}
# {'name': 'Japan', 'capital': 'Tokyo', 'region': 'Asia', 'population': 125836021}
# {'name': 'Bolivia', 'capital': 'Sucre', 'region': 'Americas', 'population': 11673029}
# {'name': 'Chile', 'capital': 'Santiago', 'region': 'Americas', 'population': 19116209}
# {'name': 'United States', 'capital': 'Washington, D.C.', 'region': 'Americas', 'population': 329484123}
# {'name': 'Saint Vincent and the Grenadines', 'capital': 'Kingstown', 'region': 'Americas', 'population': 110947}
# {'name': 'Bermuda', 'capital': 'Hamilton', 'region': 'Americas', 'population': 63903}
# {'name': 'Seychelles', 'capital': 'Victoria', 'region': 'Africa', 'population': 98462}
# {'name': 'British Indian Ocean Territory', 'capital': 'Diego Garcia', 'region': 'Africa', 'population': 3000}
# {'name': 'Guatemala', 'capital': 'Guatemala City', 'region': 'Americas', 'population': 16858333}
# {'name': 'Ecuador', 'capital': 'Quito', 'region': 'Americas', 'population': 17643060}
# {'name': 'Martinique', 'capital': 'Fort-de-France', 'region': 'Americas', 'population': 378243}
# {'name': 'Tajikistan', 'capital': 'Dushanbe', 'region': 'Asia', 'population': 9537642}
# {'name': 'Malta', 'capital': 'Valletta', 'region': 'Europe', 'population': 525285}
# {'name': 'Gambia', 'capital': 'Banjul', 'region': 'Africa', 'population': 2416664}
# {'name': 'Nigeria', 'capital': 'Abuja', 'region': 'Africa', 'population': 206139587}
# {'name': 'Bahamas', 'capital': 'Nassau', 'region': 'Americas', 'population': 393248}
# {'name': 'Kosovo', 'capital': 'Pristina', 'region': 'Europe', 'population': 1775378}
# {'name': 'Kuwait', 'capital': 'Kuwait City', 'region': 'Asia', 'population': 4270563}
# {'name': 'Maldives', 'capital': 'Malé', 'region': 'Asia', 'population': 540542}
# {'name': 'South Sudan', 'capital': 'Juba', 'region': 'Africa', 'population': 11193729}
# {'name': 'Iran', 'capital': 'Tehran', 'region': 'Asia', 'population': 83992953}
# {'name': 'Albania', 'capital': 'Tirana', 'region': 'Europe', 'population': 2837743}
# {'name': 'Brazil', 'capital': 'Brasília', 'region': 'Americas', 'population': 212559409}
# {'name': 'Serbia', 'capital': 'Belgrade', 'region': 'Europe', 'population': 6908224}
# {'name': 'Belize', 'capital': 'Belmopan', 'region': 'Americas', 'population': 397621}
# {'name': 'Myanmar', 'capital': 'Naypyidaw', 'region': 'Asia', 'population': 54409794}
# {'name': 'Bhutan', 'capital': 'Thimphu', 'region': 'Asia', 'population': 771612}
# {'name': 'Venezuela', 'capital': 'Caracas', 'region': 'Americas', 'population': 28435943}
# {'name': 'Liberia', 'capital': 'Monrovia', 'region': 'Africa', 'population': 5057677}
# {'name': 'Jamaica', 'capital': 'Kingston', 'region': 'Americas', 'population': 2961161}
# {'name': 'Poland', 'capital': 'Warsaw', 'region': 'Europe', 'population': 37950802}
# {'name': 'Cayman Islands', 'capital': 'George Town', 'region': 'Americas', 'population': 65720}
# {'name': 'Brunei', 'capital': 'Bandar Seri Begawan', 'region': 'Asia', 'population': 437483}
# {'name': 'Comoros', 'capital': 'Moroni', 'region': 'Africa', 'population': 869595}
# {'name': 'Guam', 'capital': 'Hagåtña', 'region': 'Oceania', 'population': 168783}
# {'name': 'Tonga', 'capital': "Nuku'alofa", 'region': 'Oceania', 'population': 105697}
# {'name': 'Kiribati', 'capital': 'South Tarawa', 'region': 'Oceania', 'population': 119446}
# {'name': 'Ghana', 'capital': 'Accra', 'region': 'Africa', 'population': 31072945}
# {'name': 'Chad', 'capital': "N'Djamena", 'region': 'Africa', 'population': 16425859}
# {'name': 'Zimbabwe', 'capital': 'Harare', 'region': 'Africa', 'population': 14862927}
# {'name': 'Saint Martin', 'capital': 'Marigot', 'region': 'Americas', 'population': 38659}
# {'name': 'Mongolia', 'capital': 'Ulan Bator', 'region': 'Asia', 'population': 3278292}
# {'name': 'Portugal', 'capital': 'Lisbon', 'region': 'Europe', 'population': 10305564}
# {'name': 'American Samoa', 'capital': 'Pago Pago', 'region': 'Oceania', 'population': 55197}
# {'name': 'Republic of the Congo', 'capital': 'Brazzaville', 'region': 'Africa', 'population': 5657000}
# {'name': 'Belgium', 'capital': 'Brussels', 'region': 'Europe', 'population': 11555997}
# {'name': 'Israel', 'capital': 'Jerusalem', 'region': 'Asia', 'population': 9216900}
# {'name': 'New Zealand', 'capital': 'Wellington', 'region': 'Oceania', 'population': 5084300}
# {'name': 'Nicaragua', 'capital': 'Managua', 'region': 'Americas', 'population': 6624554}
# {'name': 'Anguilla', 'capital': 'The Valley', 'region': 'Americas', 'population': 13452}

# %% [markdown]
# CONEXÃO COM 3ª API PARA EXTRAÇÃO DE UMA TABELA

# %%
# Importação das Bibliotecas

import requests
from plyer import notification

# %%
# Extraindo dados da API

# Seção 2: Função para Extrair Dados da API
def get_pokemon_data(url):
    try:
        response = requests.get(url)
        response.raise_for_status()  # Levanta um erro para códigos de status HTTP 4xx/5xx
        data = response.json()
        return data
    except requests.RequestException as e:
        # Se ocorrer um erro na requisição, notifique e retorne None
        notification.notify(
            title="Erro na Requisição",
            message=f"Erro ao acessar a API: {e}",
            timeout=10
        )
        return None

# %%
# Processamento dos Dados

# Seção 3: Processamento dos Dados
def process_pokemon_data(data):
    if data is None:
        return
    
    pokemon_list = []
    results = data.get('results', [])
    
    for pokemon in results:
        name = pokemon.get('name')
        url = pokemon.get('url')
        pokemon_list.append({'name': name, 'url': url})
    
    return pokemon_list

# %%
# Código Principal

# Seção 4: Código Principal
def main():
    api_url = "https://pokeapi.co/api/v2/pokemon"
    data = get_pokemon_data(api_url)
    
    if data:
        pokemon_list = process_pokemon_data(data)
        print("Lista de Pokémons:")
        for pokemon in pokemon_list:
            print(f"Nome: {pokemon['name']}, URL: {pokemon['url']}")
    else:
        print("Não foi possível recuperar dados da API.")
        
if __name__ == "__main__":
    main()
# Out:
# Lista de Pokémons:
# Nome: bulbasaur, URL: https://pokeapi.co/api/v2/pokemon/1/
# Nome: ivysaur, URL: https://pokeapi.co/api/v2/pokemon/2/
# Nome: venusaur, URL: https://pokeapi.co/api/v2/pokemon/3/
# Nome: charmander, URL: https://pokeapi.co/api/v2/pokemon/4/
# Nome: charmeleon, URL: https://pokeapi.co/api/v2/pokemon/5/
# Nome: charizard, URL: https://pokeapi.co/api/v2/pokemon/6/
# Nome: squirtle, URL: https://pokeapi.co/api/v2/pokemon/7/
# Nome: wartortle, URL: https://pokeapi.co/api/v2/pokemon/8/
# Nome: blastoise, URL: https://pokeapi.co/api/v2/pokemon/9/
# Nome: caterpie, URL: https://pokeapi.co/api/v2/pokemon/10/
# Nome: metapod, URL: https://pokeapi.co/api/v2/pokemon/11/
# Nome: butterfree, URL: https://pokeapi.co/api/v2/pokemon/12/
# Nome: weedle, URL: https://pokeapi.co/api/v2/pokemon/13/
# Nome: kakuna, URL: https://pokeapi.co/api/v2/pokemon/14/
# Nome: beedrill, URL: https://pokeapi.co/api/v2/pokemon/15/
# Nome: pidgey, URL: https://pokeapi.co/api/v2/pokemon/16/
# Nome: pidgeotto, URL: https://pokeapi.co/api/v2/pokemon/17/
# Nome: pidgeot, URL: https://pokeapi.co/api/v2/pokemon/18/
# Nome: rattata, URL: https://pokeapi.co/api/v2/pokemon/19/
# Nome: raticate, URL: https://pokeapi.co/api/v2/pokemon/20/
